# %% [markdown]
# Load Crop Dimension

# %%
import pandas as pd
import numpy as np
cropDF = pd.read_csv("./datasets/CropDimension.csv")
cropDF
# Out:
# C:\Users\daniel\AppData\Local\Temp\ipykernel_11692\416333319.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#    Crop_ID Common Name              Species        Family  \
# 0        0       Wheat             Triticum         Grass
# 1        1       Durum             Triticum         Grass
# 2        2        Oats         Avena sativa         Grass
# 3        3      Barley              Hordeum         Grass
# 4        4         Rye               Secale         Grass
# 5        5    Flaxseed  Linum usitatissimum      Linaceae
# 6        6      Canola       Brassica napus  Brassicaceae
#
# ...

# %% [markdown]
# Load alberta crops data

# %%
albertaDF = pd.read_csv("./datasets/raw/crop_data/alberta_main.csv")
# ontarioDF
albertaDF = albertaDF[['REF_DATE', 'GEO', 'Type of grain','VALUE']]
albertaDF['REF_DATE'] = pd.to_datetime(albertaDF['REF_DATE'])
albertaDF.rename(columns={'REF_DATE': 'Date', 'GEO': 'Province', 'VALUE':'Volume','Type of grain':'Product'}, inplace=True)
unique_values = albertaDF['Product'].unique()
print(unique_values)
replace_dict = {'Wheat, excluding durum': 'Wheat','Durum wheat': 'Durum', 'Canola (rapeseed)': 'Canola'}
albertaDF['Product'] = albertaDF['Product'].replace(replace_dict)
albertaDF
# Out:
# ['Wheat, excluding durum' 'Durum wheat' 'Oats' 'Barley' 'Rye' 'Flaxseed'
#  'Canola (rapeseed)']
#            Date Province Product  Volume
# 0    2001-01-01  Alberta   Wheat  619117
# 1    2001-02-01  Alberta   Wheat  375113
# 2    2001-03-01  Alberta   Wheat  309619
# 3    2001-04-01  Alberta   Wheat  382852
# 4    2001-05-01  Alberta   Wheat  445880
# ...         ...      ...     ...     ...
# 1927 2023-08-01  Alberta  Canola  187881
# 1928 2023-09-01  Alberta  Canola  545946
# 1929 2023-10-01  Alberta  Canola  483451
# 1930 2023-11-01  Alberta  Canola  539209
# 1931 2023-12-01  Alberta  Canola  298227
#
# [1932 rows x 4 columns]

# %% [markdown]
# Load British Columbia crops data

# %%
britishcolumbiaDF = pd.read_csv("./datasets/raw/crop_data/britishcolumbia_main.csv")
# ontarioDF
britishcolumbiaDF = britishcolumbiaDF[['REF_DATE', 'GEO', 'Type of grain','VALUE']]
britishcolumbiaDF['REF_DATE'] = pd.to_datetime(britishcolumbiaDF['REF_DATE'])
britishcolumbiaDF.rename(columns={'REF_DATE': 'Date', 'GEO': 'Province', 'VALUE':'Volume','Type of grain':'Product'}, inplace=True)
unique_values = britishcolumbiaDF['Product'].unique()
print(unique_values)
replace_dict = {'Wheat, excluding durum': 'Wheat','Durum wheat': 'Durum', 'Canola (rapeseed)': 'Canola'}
britishcolumbiaDF['Product'] = britishcolumbiaDF['Product'].replace(replace_dict)
britishcolumbiaDF
# Out:
# ['Wheat, excluding durum' 'Durum wheat' 'Oats' 'Barley' 'Rye' 'Flaxseed'
#  'Canola (rapeseed)']
#            Date          Province Product  Volume
# 0    2001-01-01  British Columbia   Wheat    9855
# 1    2001-02-01  British Columbia   Wheat    7041
# 2    2001-03-01  British Columbia   Wheat    4949
# 3    2001-04-01  British Columbia   Wheat    3333
# 4    2001-05-01  British Columbia   Wheat    2654
# ...         ...               ...     ...     ...
# 1927 2023-08-01  British Columbia  Canola    1289
# 1928 2023-09-01  British Columbia  Canola   11373
# 1929 2023-10-01  British Columbia  Canola    9459
# 1930 2023-11-01  British Columbia  Canola    5500
# 1931 2023-12-01  British Columbia  Canola    7828
#
# [1932 rows x 4 columns]

# %% [markdown]
# Load Manitoba Crop Data

# %%
manitobaDF = pd.read_csv("./datasets/raw/crop_data/manitoba_main.csv")
# ontarioDF
manitobaDF = manitobaDF[['REF_DATE', 'GEO', 'Type of grain','VALUE']]
manitobaDF['REF_DATE'] = pd.to_datetime(manitobaDF['REF_DATE'])
manitobaDF.rename(columns={'REF_DATE': 'Date', 'GEO': 'Province', 'VALUE':'Volume','Type of grain':'Product'}, inplace=True)
unique_values = manitobaDF['Product'].unique()
print(unique_values)
replace_dict = {'Wheat, excluding durum': 'Wheat','Durum wheat': 'Durum', 'Canola (rapeseed)': 'Canola'}
manitobaDF['Product'] = manitobaDF['Product'].replace(replace_dict)
manitobaDF
# Out:
# ['Wheat, excluding durum' 'Durum wheat' 'Oats' 'Barley' 'Rye' 'Flaxseed'
#  'Canola (rapeseed)']
#            Date  Province Product    Volume
# 0    2001-01-01  Manitoba   Wheat  312009.0
# 1    2001-02-01  Manitoba   Wheat  192954.0
# 2    2001-03-01  Manitoba   Wheat  213051.0
# 3    2001-04-01  Manitoba   Wheat  287132.0
# 4    2001-05-01  Manitoba   Wheat  299690.0
# ...         ...       ...     ...       ...
# 1927 2023-08-01  Manitoba  Canola  203241.0
# 1928 2023-09-01  Manitoba  Canola  373157.0
# 1929 2023-10-01  Manitoba  Canola  259269.0
# 1930 2023-11-01  Manitoba  Canola  256427.0
# 1931 2023-12-01  Manitoba  Canola  172290.0
#
# [1932 rows x 4 columns]

# %% [markdown]
# Load Ontario crops data

# %%
ontarioDF = pd.read_csv("./datasets/raw/crop_data/ontario_main.csv")
# ontarioDF
ontarioDF = ontarioDF[['REF_DATE', 'GEO', 'Type of grain','VALUE']]
ontarioDF['REF_DATE'] = pd.to_datetime(ontarioDF['REF_DATE'])
ontarioDF.rename(columns={'REF_DATE': 'Date', 'GEO': 'Province', 'VALUE':'Volume','Type of grain':'Product'}, inplace=True)
unique_values = ontarioDF['Product'].unique()
print(unique_values)
replace_dict = {'Wheat, excluding durum': 'Wheat', 'Canola (rapeseed)': 'Canola'}
ontarioDF['Product'] = ontarioDF['Product'].replace(replace_dict)
ontarioDF
# Out:
# ['Wheat, excluding durum' 'Oats' 'Barley' 'Canola (rapeseed)']
#            Date Province Product    Volume
# 0    2001-08-01  Ontario   Wheat  332832.0
# 1    2001-09-01  Ontario   Wheat   71065.0
# 2    2001-10-01  Ontario   Wheat   24441.0
# 3    2001-11-01  Ontario   Wheat    9526.0
# 4    2001-12-01  Ontario   Wheat    7097.0
# ...         ...      ...     ...       ...
# 1071 2023-08-01  Ontario  Canola    5764.0
# 1072 2023-09-01  Ontario  Canola    6931.0
# 1073 2023-10-01  Ontario  Canola   10605.0
# 1074 2023-11-01  Ontario  Canola    2127.0
# 1075 2023-12-01  Ontario  Canola    3438.0
#
# [1076 rows x 4 columns]

# %% [markdown]
# Load Quebec crop data

# %%
quebecDF = pd.read_csv("./datasets/raw/crop_data/quebec_main.csv")
# ontarioDF
quebecDF = quebecDF[['REF_DATE', 'GEO', 'Type of grain','VALUE']]
quebecDF['REF_DATE'] = pd.to_datetime(quebecDF['REF_DATE'])
quebecDF.rename(columns={'REF_DATE': 'Date', 'GEO': 'Province', 'VALUE':'Volume','Type of grain':'Product'}, inplace=True)
unique_values = quebecDF['Product'].unique()
print(unique_values)
replace_dict = {'Wheat, excluding durum': 'Wheat','Durum wheat': 'Durum', 'Canola (rapeseed)': 'Canola'}
quebecDF['Product'] = quebecDF['Product'].replace(replace_dict)
quebecDF
# Out:
# ['Wheat, excluding durum' 'Oats' 'Barley' 'Canola (rapeseed)']
#            Date Province Product  Volume
# 0    2001-08-01   Quebec   Wheat   710.0
# 1    2001-09-01   Quebec   Wheat   710.0
# 2    2001-10-01   Quebec   Wheat   710.0
# 3    2001-11-01   Quebec   Wheat  1130.0
# 4    2001-12-01   Quebec   Wheat   710.0
# ...         ...      ...     ...     ...
# 1071 2023-08-01   Quebec  Canola   312.0
# 1072 2023-09-01   Quebec  Canola  2362.0
# 1073 2023-10-01   Quebec  Canola  7635.0
# 1074 2023-11-01   Quebec  Canola  3026.0
# 1075 2023-12-01   Quebec  Canola  1256.0
#
# [1076 rows x 4 columns]

# %% [markdown]
# Load Saskatchewan crop data

# %%
saskatchewanDF = pd.read_csv("./datasets/raw/crop_data/saskatchewan_main.csv")
# ontarioDF
saskatchewanDF = saskatchewanDF[['REF_DATE', 'GEO', 'Type of grain','VALUE']]
saskatchewanDF['REF_DATE'] = pd.to_datetime(saskatchewanDF['REF_DATE'])
saskatchewanDF.rename(columns={'REF_DATE': 'Date', 'GEO': 'Province', 'VALUE':'Volume','Type of grain':'Product'}, inplace=True)
unique_values = saskatchewanDF['Product'].unique()
print(unique_values)
replace_dict = {'Wheat, excluding durum': 'Wheat','Durum wheat': 'Durum', 'Canola (rapeseed)': 'Canola'}
saskatchewanDF['Product'] = saskatchewanDF['Product'].replace(replace_dict)
saskatchewanDF
# Out:
# ['Wheat, excluding durum' 'Durum wheat' 'Oats' 'Barley' 'Rye' 'Flaxseed'
#  'Canola (rapeseed)']
#            Date      Province Product  Volume
# 0    2001-01-01  Saskatchewan   Wheat  785342
# 1    2001-02-01  Saskatchewan   Wheat  478352
# 2    2001-03-01  Saskatchewan   Wheat  418005
# 3    2001-04-01  Saskatchewan   Wheat  432343
# 4    2001-05-01  Saskatchewan   Wheat  640998
# ...         ...           ...     ...     ...
# 1927 2023-08-01  Saskatchewan  Canola  577734
# 1928 2023-09-01  Saskatchewan  Canola  962474
# 1929 2023-10-01  Saskatchewan  Canola  734746
# 1930 2023-11-01  Saskatchewan  Canola  830464
# 1931 2023-12-01  Saskatchewan  Canola  596491
#
# [1932 rows x 4 columns]

# %% [markdown]
# Load Crop Prices

# %%
cropPricesDF = pd.read_csv("./datasets/raw/crop_data/crops_prices.csv")
cropPricesDF = cropPricesDF[['REF_DATE', 'GEO', 'Farm products','VALUE']]
cropPricesDF['REF_DATE'] = pd.to_datetime(cropPricesDF['REF_DATE'])
cropPricesDF.rename(columns={'REF_DATE': 'Date', 'GEO': 'Province', 'VALUE':'Price','Farm products':'Product'}, inplace=True)
replace_dict = {'Wheat (except durum wheat) [1121111]': 'Wheat', 'Rye [1151152]': 'Rye', 'Oats [115113111]': 'Oats', 'Barley [1151141]': 'Barley', 'Canola (including rapeseed) [113111]': 'Canola', 'Durum wheat [112111211]': 'Durum', 'Flaxseed [115122111]': 'Flaxseed'}
cropPricesDF['Product'] = cropPricesDF['Product'].replace(replace_dict)
cropPricesDF
# Out:
#            Date          Province Product   Price
# 0    2001-01-01            Quebec   Wheat  144.96
# 1    2001-02-01            Quebec   Wheat  145.04
# 2    2001-03-01            Quebec   Wheat  137.06
# 3    2001-04-01            Quebec   Wheat  144.89
# 4    2001-05-01            Quebec   Wheat  151.40
# ...         ...               ...     ...     ...
# 8311 2023-08-01  British Columbia     Rye  325.62
# 8312 2023-09-01  British Columbia     Rye     NaN
# 8313 2023-10-01  British Columbia     Rye     NaN
# 8314 2023-11-01  British Columbia     Rye     NaN
# 8315 2023-12-01  British Columbia     Rye     NaN
#
# [8316 rows x 4 columns]

# %%
dataframes = [quebecDF,ontarioDF,saskatchewanDF,britishcolumbiaDF,ontarioDF,manitobaDF,albertaDF]
mergeColumns = ['Date','Province','Product']
finalVolume_DF = pd.concat(dataframes, ignore_index=True)
print(len(finalVolume_DF))
cropPricesDF = pd.merge(cropPricesDF, finalVolume_DF, how='left', on=mergeColumns)
#Convert 0 values to NaN for processing
cropPricesDF['Volume'] = cropPricesDF['Volume'].replace(0, np.nan)
cropPricesDF['Price'] = cropPricesDF['Price'].replace(0, np.nan)



# Count NaN values in the 'volume' and 'price' columns
nan_count_volume = cropPricesDF['Volume'].isna().sum()
nan_count_crop_prices = cropPricesDF['Price'].isna().sum()
print(f"Number of NaN values in 'crop_prices': {nan_count_crop_prices}")
print(f"Number of NaN values in 'volume': {nan_count_volume}")


# Drop rows where both price and Volume is NaN
cropPricesDF = cropPricesDF.dropna(subset=['Price', 'Volume'], how='all')
# Out:
# 10956
# Number of NaN values in 'crop_prices': 707
# Number of NaN values in 'volume': 1052

# %%
#Incorporate forward and backward fill for missing crop_prices and volume

price_ffill = cropPricesDF['Price'].ffill()


price_bfill = cropPricesDF['Price'].bfill()

# Calculate the mean of ffill and bfill series
mean_fill_series = (price_ffill + price_bfill) / 2
# Calculate global mean for remaining NaN prices
global_mean = cropPricesDF['Price'].mean()


cropPricesDF['Price'] = cropPricesDF['Price'].fillna(mean_fill_series)

cropPricesDF['Price'] = cropPricesDF['Price'].fillna(global_mean)

#Repeat process for Volume
volume_ffill = cropPricesDF['Volume'].ffill()

# Backward fill (bfill) to fill NaNs
volume_bfill = cropPricesDF['Volume'].bfill()

# Calculate the mean of ffill and bfill series
mean_fill_series = (volume_ffill + volume_bfill) / 2
global_mean = cropPricesDF['Volume'].mean()

# Assign the mean of ffill and bfill to NaN values in the original column
cropPricesDF['Volume'] = cropPricesDF['Volume'].fillna(mean_fill_series)

cropPricesDF['Volume'] = cropPricesDF['Volume'].fillna(global_mean)
cropFactTable = cropPricesDF

# zero_count_price = (cropPricesDF['Price'] == 0).sum()
# zero_count_volume = (cropPricesDF['Volume'] == 0).sum()
# nan_count_volume = cropPricesDF['Volume'].isna().sum()
# nan_count_crop_prices = cropPricesDF['Price'].isna().sum()
# print(f"Number of NaN values in 'crop_prices': {nan_count_crop_prices}")
# print(f"Number of NaN values in 'volume': {nan_count_volume}")
# print(zero_count_price)
# print(zero_count_volume)

# %% [markdown]
# Add Date-ID to fact table

# %%
#Add Date_ID
dateDF = pd.read_csv("./datasets/dates_dim.csv")
dateDF['Date'] = pd.to_datetime(dateDF['Date'])
cropFactTable= pd.merge(cropFactTable, dateDF[['Date', 'Date_ID']], on=['Date'], how='left')
cropFactTable
# Out:
#            Date          Province Product    Price        Volume  Date_ID
# 0    2001-01-01            Quebec   Wheat  144.960  97889.085987        0
# 1    2001-02-01            Quebec   Wheat  145.040  97889.085987        1
# 2    2001-03-01            Quebec   Wheat  137.060  97889.085987        2
# 3    2001-04-01            Quebec   Wheat  144.890  97889.085987        3
# 4    2001-05-01            Quebec   Wheat  151.400  97889.085987        4
# ...         ...               ...     ...      ...           ...      ...
# 8771 2023-03-01  British Columbia     Rye  330.420     40.500000      266
# 8772 2023-04-01  British Columbia     Rye  321.860     49.000000      267
# 8773 2023-06-01  British Columbia     Rye  310.470     27.000000      269
# 8774 2023-07-01  British Columbia     Rye  318.045      5.000000      270
# 8775 2023-08-01  British Columbia     Rye  325.620  97889.085987      271
#
# [8776 rows x 6 columns]

# %% [markdown]
# Add Crop_ID

# %%
cropDF = pd.read_csv("./datasets/CropDimension.csv")
cropDF.rename(columns={'Common Name': 'Product'}, inplace=True)
cropFactTable= pd.merge(cropFactTable, cropDF[['Product', 'Crop_ID']], on=['Product'], how='left')
cropFactTable
# Out:
#            Date          Province Product    Price        Volume  Date_ID  \
# 0    2001-01-01            Quebec   Wheat  144.960  97889.085987        0
# 1    2001-02-01            Quebec   Wheat  145.040  97889.085987        1
# 2    2001-03-01            Quebec   Wheat  137.060  97889.085987        2
# 3    2001-04-01            Quebec   Wheat  144.890  97889.085987        3
# 4    2001-05-01            Quebec   Wheat  151.400  97889.085987        4
# ...         ...               ...     ...      ...           ...      ...
# 8771 2023-03-01  British Columbia     Rye  330.420     40.500000      266
# 8772 2023-04-01  British Columbia     Rye  321.860     49.000000      267
# 8773 2023-06-01  British Columbia     Rye  310.470     27.000000      269
# 8774 2023-07-01  British Columbia     Rye  318.045      5.000000      270
# 8775 2023-08-01  British Columbia     Rye  325.620  97889.085987      271
#
#       Crop_ID
# 0           0
# 1           0
# 2           0
# 3           0
# ...

# %% [markdown]
# Add Climate_ID

# %%
#Add CLimate_ID
climateDF = pd.read_csv("datasets/temp/climate_dimension.csv")
climateDF.rename(columns={'Unnamed: 0': 'Climate_ID'}, inplace=True)
climateDF['Date'] = pd.to_datetime(climateDF['Month'])

replace_Province = {'BC' : 'British Columbia', 'AB':'Alberta', 'SK' : 'Saskatchewan', 'MB':'Manitoba', 'ON':'Ontario','QC' :'Quebec'}
climateDF['Province'] = climateDF['Province'].replace(replace_Province)


cropFactTable= pd.merge(cropFactTable, climateDF[['Date', 'Province', 'Climate_ID']], on=['Date', 'Province'], how='left')
cropFactTable
# Out:
#            Date          Province Product    Price        Volume  Date_ID  \
# 0    2001-01-01            Quebec   Wheat  144.960  97889.085987        0
# 1    2001-02-01            Quebec   Wheat  145.040  97889.085987        1
# 2    2001-03-01            Quebec   Wheat  137.060  97889.085987        2
# 3    2001-04-01            Quebec   Wheat  144.890  97889.085987        3
# 4    2001-05-01            Quebec   Wheat  151.400  97889.085987        4
# ...         ...               ...     ...      ...           ...      ...
# 8771 2023-03-01  British Columbia     Rye  330.420     40.500000      266
# 8772 2023-04-01  British Columbia     Rye  321.860     49.000000      267
# 8773 2023-06-01  British Columbia     Rye  310.470     27.000000      269
# 8774 2023-07-01  British Columbia     Rye  318.045      5.000000      270
# 8775 2023-08-01  British Columbia     Rye  325.620  97889.085987      271
#
#       Crop_ID  Climate_ID
# 0           0           5
# ...

# %%
climateDF = pd.read_csv("datasets/temp/climate_dimension.csv")
climateDF
# Out:
#       Unnamed: 0    Month Province  Mean_Temp   Min_Temp   Max_Temp  \
# 0              0  2001-01       BC   0.351884  -8.668497   8.602305
# 1              1  2001-01       AB  -4.457322 -18.166109   8.743096
# 2              2  2001-01       SK  -8.665789 -24.729032   4.388312
# 3              3  2001-01       MB -12.049573 -29.186325   2.558974
# 4              4  2001-01       ON  -7.284188 -24.331624   2.815385
# ...          ...      ...      ...        ...        ...        ...
# 1651        1651  2023-12       AB  -2.315918 -16.090650  10.993496
# 1652        1652  2023-12       SK  -4.930667 -18.025333   8.026667
# 1653        1653  2023-12       MB  -6.992424 -21.728788   6.106061
# 1654        1654  2023-12       ON  -1.208125 -13.249375   9.453750
# 1655        1655  2023-12       QC  -5.273333 -19.317391   8.928019
#
#       Mean_Diff_from_Normal   Snowfall  Percent_of_Normal_Snowfall  \
# 0                  1.891500  18.861538                   36.088106
# ...

# %% [markdown]
# Add Region_ID

# %%
#Add Region_ID
regionDF = pd.read_csv("./datasets/region_dim.csv")
regionDF.rename(columns={'Name_EN': 'Province', 'EffectiveDate': 'Date'}, inplace=True)
regionDF['Date'] = pd.to_datetime(regionDF['Date'])


#Crop ID for QC,MN,Alberta
cropFactTable= pd.merge(cropFactTable, regionDF[['Province', 'Region_ID']], on=['Province'], how='left')

#Crop ID for BC
cropFactTable.loc[(cropFactTable['Province'] == 'British Columbia') & (cropFactTable['Date'] < '2018-07-01'), 'Region_ID'] = 13
cropFactTable.loc[(cropFactTable['Province'] == 'British Columbia')  & (cropFactTable['Date'] >= '2018-07-01'),'Region_ID'] = 14


#Crop ID for ON
cropFactTable.loc[(cropFactTable['Province'] == 'Ontario') & (cropFactTable['Date'] < '2022-04-01'), 'Region_ID'] = 7
cropFactTable.loc[(cropFactTable['Province'] == 'Ontario') & (cropFactTable['Date'] >= '2022-04-01') ,'Region_ID'] = 6

#Crop ID for SW
cropFactTable.loc[(cropFactTable['Province'] == 'Saskatchewan') & (cropFactTable['Date'] < '2001-10-01'), 'Region_ID'] = 9
cropFactTable.loc[(cropFactTable['Province'] == 'Saskatchewan') & (cropFactTable['Date'] >= '2001-10-01') & (cropFactTable['Date'] <= '2007-07-01'), 'Region_ID'] = 10
cropFactTable.loc[(cropFactTable['Province'] == 'Saskatchewan') & (cropFactTable['Date'] > '2007-07-01'), 'Region_ID'] = 11
cropFactTable = cropFactTable.drop(['Province', 'Date','Product'], axis=1)
#Shifting columns
new_order = ['Date_ID','Crop_ID','Climate_ID','Region_ID','Price','Volume']
cropFactTable = cropFactTable[new_order]
cropFactTable =  cropFactTable.drop_duplicates()
cropFactTable= cropFactTable.reset_index(drop=True)
cropFactTable.to_csv('cropFactTable.csv', index=False)
cropFactTable
# Out:
#       Date_ID  Crop_ID  Climate_ID  Region_ID    Price        Volume
# 0           0        0           5          5  144.960  97889.085987
# 1           1        0          11          5  145.040  97889.085987
# 2           2        0          17          5  137.060  97889.085987
# 3           3        0          23          5  144.890  97889.085987
# 4           4        0          29          5  151.400  97889.085987
# ...       ...      ...         ...        ...      ...           ...
# 7964      266        4        1596         14  330.420     40.500000
# 7965      267        4        1602         14  321.860     49.000000
# 7966      269        4        1614         14  310.470     27.000000
# 7967      270        4        1620         14  318.045      5.000000
# 7968      271        4        1626         14  325.620  97889.085987
#
# [7969 rows x 6 columns]

# %% [markdown]
# Compute Total Value Produced

# %%
pd.options.display.float_format = '{:.2f}'.format
cropFactTable['Total_Value'] = cropFactTable['Price']*cropFactTable['Volume']
cropFactTable
# Out:
#       Date_ID  Crop_ID  Climate_ID  Region_ID  Price   Volume  Total_Value
# 0           0        0           5          5 144.96 97889.09  14190001.90
# 1           1        0          11          5 145.04 97889.09  14197833.03
# 2           2        0          17          5 137.06 97889.09  13416678.13
# 3           3        0          23          5 144.89 97889.09  14183149.67
# 4           4        0          29          5 151.40 97889.09  14820407.62
# ...       ...      ...         ...        ...    ...      ...          ...
# 7964      266        4        1596         14 330.42    40.50     13382.01
# 7965      267        4        1602         14 321.86    49.00     15771.14
# 7966      269        4        1614         14 310.47    27.00      8382.69
# 7967      270        4        1620         14 318.05     5.00      1590.23
# 7968      271        4        1626         14 325.62 97889.09  31874644.18
#
# [7969 rows x 7 columns]

# %%
cropFactTable.to_csv('datasets\cropFactTable.csv')
