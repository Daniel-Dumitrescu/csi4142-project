# %%
import pandas as pd
import math
# Out:
# C:\Users\daniel\AppData\Local\Temp\ipykernel_5164\3795637154.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# Binning

# %%
region_df = pd.read_csv('datasets/region_dim.csv')
region_df.head()
# Out:
#    Region_ID           Name_EN               Name_FR Abbrev_EN Abbrev_FR  \
# 0          0           Alberta               Alberta     Alta.      Alb.
# 1          1          Atlantic                   NaN       NaN       NaN
# 2          2  British Columbia  Colombie-Britannique      B.C.     C.-B.
# 3          3  British Columbia  Colombie-Britannique      B.C.     C.-B.
# 4          4            Canada                   NaN       NaN       NaN
#
#   AlphaCode  NumericCode GeographicRegion  Area_Percent       Area       Land  \
# 0        AB           48         Prairies           6.6   661848.0   642317.0
# 1       NaN            1           Canada           5.5   539064.0   504320.0
# 2        BC           59           Canada           9.5   944735.0   925186.0
# 3        BC           59           Canada           9.5   944735.0   925186.0
# 4       NaN            0              NaN         100.0  9984670.0  9093507.0
#
#    LandOfArea_Percent  Freshwater  FreshwaterOfArea_Percent EffectiveDate  \
# 0           97.049020     19531.0                  2.950980    2001-01-01
# 1           93.554754     34744.0                  6.445246    2001-01-01
# 2           97.930742     19549.0                  2.069258    2001-01-01
# 3           97.930742     19549.0                  2.069258    2018-07-01
# 4           91.074687    891163.0                  8.925313    2001-01-01
#
#    Population_Lower  Population_Upper
# 0           1000000           5000000
# 1           1000000           5000000
# 2           1000000           5000000
# 3           5000000          10000000
# 4          15000000          50000000

# %%
binned_df = pd.DataFrame()

for col in ['Area','Land','LandOfArea_Percent','Freshwater','FreshwaterOfArea_Percent']:
        binned_df[col + '_Binned'] = pd.qcut(region_df[col], q=math.ceil(math.sqrt(len(region_df[col]))),duplicates='drop')
        binned_df[col + '_Binned_Encoded'] = pd.qcut(region_df[col], q=math.ceil(math.sqrt(len(region_df[col]))),duplicates='drop',labels=False)

binned_df.head(20)
# Out:
#                Area_Binned  Area_Binned_Encoded             Land_Binned  \
# 0     (651036.0, 944735.0]                    2    (591670.0, 917741.0]
# 1     (420658.2, 651036.0]                    1    (393975.8, 591670.0]
# 2     (651036.0, 944735.0]                    2   (917741.0, 1328719.4]
# 3     (651036.0, 944735.0]                    2   (917741.0, 1328719.4]
# 4   (1502866.0, 9984670.0]                    4  (1328719.4, 9093507.0]
# 5     (420658.2, 651036.0]                    1    (393975.8, 591670.0]
# 6     (5659.999, 420658.2]                    0    (5659.999, 393975.8]
# 7     (5659.999, 420658.2]                    0    (5659.999, 393975.8]
# 8    (944735.0, 1502866.0]                    3   (917741.0, 1328719.4]
# 9     (5659.999, 420658.2]                    0    (5659.999, 393975.8]
# 10    (5659.999, 420658.2]                    0    (5659.999, 393975.8]
# 11  (1502866.0, 9984670.0]                    4  (1328719.4, 9093507.0]
# 12   (944735.0, 1502866.0]                    3    (591670.0, 917741.0]
# 13   (944735.0, 1502866.0]                    3    (591670.0, 917741.0]
# 14  (1502866.0, 9984670.0]                    4  (1328719.4, 9093507.0]
# 15    (5659.999, 420658.2]                    0    (5659.999, 393975.8]
# 16  (1502866.0, 9984670.0]                    4  (1328719.4, 9093507.0]
# 17    (420658.2, 651036.0]                    1    (393975.8, 591670.0]
# 18    (420658.2, 651036.0]                    1    (393975.8, 591670.0]
# 19    (420658.2, 651036.0]                    1    (393975.8, 591670.0]
#
#     Land_Binned_Encoded    LandOfArea_Percent_Binned  \
# 0                     2             (93.131, 97.754]
# 1                     1             (93.131, 97.754]
# 2                     3              (97.754, 100.0]
# 3                     3              (97.754, 100.0]
# 4                     4             (88.997, 91.113]
# 5                     1  (85.25999999999999, 88.997]
# 6                     0              (97.754, 100.0]
# 7                     0             (91.113, 93.131]
# 8                     3  (85.25999999999999, 88.997]
# 9                     0             (93.131, 97.754]
# 10                    0             (93.131, 97.754]
# 11                    4             (91.113, 93.131]
# 12                    2  (85.25999999999999, 88.997]
# 13                    2  (85.25999999999999, 88.997]
# 14                    4             (91.113, 93.131]
# 15                    0              (97.754, 100.0]
# 16                    4  (85.25999999999999, 88.997]
# 17                    1             (88.997, 91.113]
# 18                    1             (88.997, 91.113]
# 19                    1             (88.997, 91.113]
#
#     LandOfArea_Percent_Binned_Encoded     Freshwater_Binned  \
# 0                                   3    (10347.8, 32701.6]
# 1                                   3    (32701.6, 80291.0]
# 2                                   4    (10347.8, 32701.6]
# 3                                   4    (10347.8, 32701.6]
# 4                                   1  (162147.6, 891163.0]
# 5                                   0   (80291.0, 162147.6]
# 6                                   4     (-0.001, 10347.8]
# 7                                   2    (10347.8, 32701.6]
# 8                                   0  (162147.6, 891163.0]
# 9                                   3     (-0.001, 10347.8]
# 10                                  3     (-0.001, 10347.8]
# 11                                  2   (80291.0, 162147.6]
# 12                                  0   (80291.0, 162147.6]
# 13                                  0   (80291.0, 162147.6]
# 14                                  2  (162147.6, 891163.0]
# 15                                  4     (-0.001, 10347.8]
# 16                                  0  (162147.6, 891163.0]
# 17                                  1    (32701.6, 80291.0]
# 18                                  1    (32701.6, 80291.0]
# 19                                  1    (32701.6, 80291.0]
#
#     Freshwater_Binned_Encoded FreshwaterOfArea_Percent_Binned  \
# 0                           1                  (2.246, 6.869]
# 1                           2                  (2.246, 6.869]
# 2                           1                 (-0.001, 2.246]
# 3                           1                 (-0.001, 2.246]
# 4                           4                 (8.887, 11.003]
# 5                           3                (11.003, 14.739]
# 6                           0                 (-0.001, 2.246]
# 7                           1                  (6.869, 8.887]
# 8                           4                (11.003, 14.739]
# 9                           0                  (2.246, 6.869]
# 10                          0                  (2.246, 6.869]
# 11                          3                  (6.869, 8.887]
# 12                          3                (11.003, 14.739]
# 13                          3                (11.003, 14.739]
# 14                          4                  (6.869, 8.887]
# 15                          0                 (-0.001, 2.246]
# 16                          4                (11.003, 14.739]
# 17                          2                 (8.887, 11.003]
# 18                          2                 (8.887, 11.003]
# 19                          2                 (8.887, 11.003]
#
#     FreshwaterOfArea_Percent_Binned_Encoded
# 0                                         1
# 1                                         1
# 2                                         0
# 3                                         0
# 4                                         3
# 5                                         4
# 6                                         0
# 7                                         2
# 8                                         4
# 9                                         1
# 10                                        1
# 11                                        2
# 12                                        4
# 13                                        4
# 14                                        2
# 15                                        0
# 16                                        4
# 17                                        3
# 18                                        3
# 19                                        3

# %%
def encode_pop_bins(pop,bins):
    return bins.index(pop)

# %%
bins = [0, 1000000, 5000000, 10000000, 15000000, 50000000]

region_df['Population_Binned_Encoded'] = region_df['Population_Lower'].apply(encode_pop_bins,args=(bins,))
region_df.head()
# Out:
#    Region_ID           Name_EN               Name_FR Abbrev_EN Abbrev_FR  \
# 0          0           Alberta               Alberta     Alta.      Alb.
# 1          1          Atlantic                   NaN       NaN       NaN
# 2          2  British Columbia  Colombie-Britannique      B.C.     C.-B.
# 3          3  British Columbia  Colombie-Britannique      B.C.     C.-B.
# 4          4            Canada                   NaN       NaN       NaN
#
#   AlphaCode  NumericCode GeographicRegion  Area_Percent       Area       Land  \
# 0        AB           48         Prairies           6.6   661848.0   642317.0
# 1       NaN            1           Canada           5.5   539064.0   504320.0
# 2        BC           59           Canada           9.5   944735.0   925186.0
# 3        BC           59           Canada           9.5   944735.0   925186.0
# 4       NaN            0              NaN         100.0  9984670.0  9093507.0
#
#    LandOfArea_Percent  Freshwater  FreshwaterOfArea_Percent EffectiveDate  \
# 0           97.049020     19531.0                  2.950980    2001-01-01
# 1           93.554754     34744.0                  6.445246    2001-01-01
# 2           97.930742     19549.0                  2.069258    2001-01-01
# 3           97.930742     19549.0                  2.069258    2018-07-01
# 4           91.074687    891163.0                  8.925313    2001-01-01
#
#    Population_Lower  Population_Upper  Population_Binned_Encoded
# 0           1000000           5000000                          1
# 1           1000000           5000000                          1
# 2           1000000           5000000                          1
# 3           5000000          10000000                          2
# 4          15000000          50000000                          4

# %% [markdown]
# One-hot Encoding

# %%
# Crop Dimension
crop_df = pd.read_csv("datasets\CropDimension.csv")
crop_df.head()
# Out:
#    Crop_ID Common Name       Species Family  Minimum Temperature  \
# 0        0       Wheat      Triticum  Grass                    5
# 1        1       Durum      Triticum  Grass                    5
# 2        2        Oats  Avena sativa  Grass                    5
# 3        3      Barley       Hordeum  Grass                    5
# 4        4         Rye        Secale  Grass                    5
#
#    Maximum Temperature
# 0                   29
# 1                   29
# 2                   28
# 3                   28
# 4                   34

# %%
name_one_hot = pd.get_dummies(crop_df['Common Name'])
name_one_hot.head()
# Out:
#    Barley  Canola  Durum  Flaxseed   Oats    Rye  Wheat
# 0   False   False  False     False  False  False   True
# 1   False   False   True     False  False  False  False
# 2   False   False  False     False   True  False  False
# 3    True   False  False     False  False  False  False
# 4   False   False  False     False  False   True  False

# %%
species_one_hot = pd.get_dummies(crop_df['Species'])
species_one_hot.head()
# Out:
#    Avena sativa  Brassica napus  Hordeum  Linum usitatissimum  Secale  \
# 0         False           False    False                False   False
# 1         False           False    False                False   False
# 2          True           False    False                False   False
# 3         False           False     True                False   False
# 4         False           False    False                False    True
#
#    Triticum
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False

# %%
family_one_hot = pd.get_dummies(crop_df['Family'])
family_one_hot.head(10)
# Out:
#    Brassicaceae  Grass  Linaceae
# 0         False   True     False
# 1         False   True     False
# 2         False   True     False
# 3         False   True     False
# 4         False   True     False
# 5         False  False      True
# 6          True  False     False

# %%
crop_df = pd.concat([crop_df,name_one_hot,species_one_hot,family_one_hot], axis=1)
crop_df.head()
# Out:
#    Crop_ID Common Name       Species Family  Minimum Temperature  \
# 0        0       Wheat      Triticum  Grass                    5
# 1        1       Durum      Triticum  Grass                    5
# 2        2        Oats  Avena sativa  Grass                    5
# 3        3      Barley       Hordeum  Grass                    5
# 4        4         Rye        Secale  Grass                    5
#
#    Maximum Temperature  Barley  Canola  Durum  Flaxseed  ...  Wheat  \
# 0                   29   False   False  False     False  ...   True
# 1                   29   False   False   True     False  ...  False
# 2                   28   False   False  False     False  ...  False
# 3                   28    True   False  False     False  ...  False
# 4                   34   False   False  False     False  ...  False
#
#    Avena sativa  Brassica napus  Hordeum  Linum usitatissimum  Secale  \
# 0         False           False    False                False   False
# 1         False           False    False                False   False
# 2          True           False    False                False   False
# 3         False           False     True                False   False
# 4         False           False    False                False    True
#
#    Triticum  Brassicaceae  Grass  Linaceae
# 0      True         False   True     False
# 1      True         False   True     False
# 2     False         False   True     False
# 3     False         False   True     False
# 4     False         False   True     False
#
# [5 rows x 22 columns]

# %%
crop_df.to_csv("datasets/crop_dimension_encoded.csv")

# %%
# Region Dimension
region_df = pd.read_csv("datasets/region_dim.csv")
region_df.head()
# Out:
#    Region_ID           Name_EN               Name_FR Abbrev_EN Abbrev_FR  \
# 0          0           Alberta               Alberta     Alta.      Alb.
# 1          1          Atlantic                   NaN       NaN       NaN
# 2          2  British Columbia  Colombie-Britannique      B.C.     C.-B.
# 3          3  British Columbia  Colombie-Britannique      B.C.     C.-B.
# 4          4            Canada                   NaN       NaN       NaN
#
#   AlphaCode  NumericCode GeographicRegion  Area_Percent       Area       Land  \
# 0        AB           48         Prairies           6.6   661848.0   642317.0
# 1       NaN            1           Canada           5.5   539064.0   504320.0
# 2        BC           59           Canada           9.5   944735.0   925186.0
# 3        BC           59           Canada           9.5   944735.0   925186.0
# 4       NaN            0              NaN         100.0  9984670.0  9093507.0
#
#    LandOfArea_Percent  Freshwater  FreshwaterOfArea_Percent EffectiveDate  \
# 0           97.049020     19531.0                  2.950980    2001-01-01
# 1           93.554754     34744.0                  6.445246    2001-01-01
# 2           97.930742     19549.0                  2.069258    2001-01-01
# 3           97.930742     19549.0                  2.069258    2018-07-01
# 4           91.074687    891163.0                  8.925313    2001-01-01
#
#    Population_Lower  Population_Upper
# 0           1000000           5000000
# 1           1000000           5000000
# 2           1000000           5000000
# 3           5000000          10000000
# 4          15000000          50000000

# %%
name_en_one_hot = pd.get_dummies(region_df['Name_EN'])
name_en_one_hot.head()
# Out:
#    Alberta  Atlantic  British Columbia  Canada  Manitoba  New Brunswick  \
# 0     True     False             False   False     False          False
# 1    False      True             False   False     False          False
# 2    False     False              True   False     False          False
# 3    False     False              True   False     False          False
# 4    False     False             False    True     False          False
#
#    Newfoundland and Labrador  Northwest Territories  Nova Scotia  Nunavut  \
# 0                      False                  False        False    False
# 1                      False                  False        False    False
# 2                      False                  False        False    False
# 3                      False                  False        False    False
# 4                      False                  False        False    False
#
#    Ontario  Prairies  Prince Edward Island  Quebec  Saskatchewan  Territories  \
# 0    False     False                 False   False         False        False
# 1    False     False                 False   False         False        False
# 2    False     False                 False   False         False        False
# 3    False     False                 False   False         False        False
# 4    False     False                 False   False         False        False
#
#    Yukon
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
region_one_hot = pd.get_dummies(region_df['GeographicRegion'])
region_one_hot.head()
# Out:
#    Atlantic  Canada  Prairies  Territories
# 0     False   False      True        False
# 1     False    True     False        False
# 2     False    True     False        False
# 3     False    True     False        False
# 4     False   False     False        False

# %%
region_df = pd.concat([region_df,binned_df,name_en_one_hot,region_one_hot], axis=1)
region_df.head()
# Out:
#    Region_ID           Name_EN               Name_FR Abbrev_EN Abbrev_FR  \
# 0          0           Alberta               Alberta     Alta.      Alb.
# 1          1          Atlantic                   NaN       NaN       NaN
# 2          2  British Columbia  Colombie-Britannique      B.C.     C.-B.
# 3          3  British Columbia  Colombie-Britannique      B.C.     C.-B.
# 4          4            Canada                   NaN       NaN       NaN
#
#   AlphaCode  NumericCode GeographicRegion  Area_Percent       Area  ...  \
# 0        AB           48         Prairies           6.6   661848.0  ...
# 1       NaN            1           Canada           5.5   539064.0  ...
# 2        BC           59           Canada           9.5   944735.0  ...
# 3        BC           59           Canada           9.5   944735.0  ...
# 4       NaN            0              NaN         100.0  9984670.0  ...
#
#   Prairies  Prince Edward Island  Quebec  Saskatchewan  Territories  Yukon  \
# 0    False                 False   False         False        False  False
# 1    False                 False   False         False        False  False
# 2    False                 False   False         False        False  False
# 3    False                 False   False         False        False  False
# 4    False                 False   False         False        False  False
#
#    Atlantic  Canada Prairies  Territories
# 0     False   False     True        False
# 1     False    True    False        False
# 2     False    True    False        False
# 3     False    True    False        False
# 4     False   False    False        False
#
# [5 rows x 49 columns]

# %%
fact_table = pd.read_csv("datasets/cropFactTable.csv")
fact_table.head()
# Out:
#    Date_ID  Crop_ID  Climate_ID  Region_ID   Price        Volume
# 0        0        0           5          5  144.96  97889.085987
# 1        1        0          11          5  145.04  97889.085987
# 2        2        0          17          5  137.06  97889.085987
# 3        3        0          23          5  144.89  97889.085987
# 4        4        0          29          5  151.40  97889.085987

# %%
fact_table['Region_ID'].value_counts()
# Out:
# Region_ID
# 12    1667
# 8     1524
# 11    1273
# 5     1104
# 13     852
# 7      789
# 10     350
# 14     302
# 6       63
# 9       45
# Name: count, dtype: int64

# %%
fact_table['Date_ID'].value_counts()
# Out:
# Date_ID
# 206    32
# 213    32
# 240    32
# 239    32
# 238    32
#        ..
# 89     26
# 90     26
# 96     26
# 97     26
# 0      26
# Name: count, Length: 276, dtype: int64

# %%
fact_table['Crop_ID'].value_counts()
# Out:
# Crop_ID
# 2    1656
# 3    1656
# 6    1655
# 4    1039
# 0     847
# 5     828
# 1     288
# Name: count, dtype: int64
